# %% [markdown]
# #### 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %% [markdown]
# Математическое ожидание $M(X)$ и дисперсию $D(X)$ равномерно распределенной непрерывной случайной величины вычисляются по формулам:

# %% [markdown]
# $$M(X) = \frac{a + b}{2} = \frac{{200} + {800}}{2} = 500$$

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12} = \frac{(800 - 200)^2}{12} = 30 000$$

# %% [markdown]
# #### Ответ: среднее значение = 500, дисперсия = 30000

# %% [markdown]
# #### 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %% [markdown]
# $$D(X) = \frac{(b - a)^2}{12}$$

# %% [markdown]
# $$B = A \pm\sqrt{12 * D(X)}= 0.5 \pm\sqrt{12 * 0.2} = 0.5 \pm 1,55$$

# %% [markdown]
# По формуле вычисено два возможных значения B : 2,05 и -1,05. Так как правая граница не может быть меньше левой (0,5), то единственно верное значение B = 2,05

# %% [markdown]
# #### Ответ: B = 2,05

# %% [markdown]
# #### 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp**(-(x+2)**2) / 32)).
#
# Найдите:
#
# а). M(X)
#
# б). D(X)
#
# в). std(X) (среднее квадратичное отклонение)

# %% [markdown]
# $$f(x) = \frac{1}{\sigma \sqrt{2 \pi}} e ^ {- \frac{(x - a)^2}{2 \sigma^2}},$$

# %% [markdown]
# где $a = M(X), \; \sigma^2 = D(X).$

# %% [markdown]
# $$f(x) = \frac{1}{4 \sqrt{2 \pi}} e ^ {- \frac{(x - (- 2))^2}{2 * 4^2}},$$

# %% [markdown]
# #### Ответ:
#
# а). M(X) = -2
#
# б). D(X) = 16
#
# в). std(X) = 4

# %% [markdown]
# #### 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %% [markdown]
# На отрезке от −𝜎 до +𝜎
#
# расположено около 68 % наблюдений,
#
# от −2𝜎
# до +2𝜎
#
# — 95.4 %,
#
# и от −3𝜎
# до +3𝜎 — 99.72 %.
#
# #### Ответ, используя Z таблицу:
#
# а). больше 182 см = + 1*𝜎 . P = 0,15866
#
# б). больше 190 см = + 2*𝜎 . P = 0,002275
#
# в). от 166 см до 190 см = от - 1*𝜎 до + 2*𝜎 . P = 1 - 0,15866 - 0,002275 = 0,839065
#
# г). от 166 см до 182 см = от - 1*𝜎 до + 1*𝜎 . P = 1 - 0,15866 - 0,15866 = 0,68268
#
# д). от 158 см до 190 см = от - 2*𝜎 до + 2*𝜎 . P = 1 - 0,002275 - 0,002275 = 0,99545
#
# е). не выше 150 см или не ниже 190 см = меньше - 3*𝜎 или больше + 2*𝜎 . P = 0,00135 + 0.002275 = 0,003625
#
# ё). не выше 150 см или не ниже 198 см  = меньше - 3*𝜎 или больше + 3*𝜎 . P = 0,00135 + 0.00135 = 0,00270
#
# ж). ниже 166 см = - 1*𝜎 . P = 0,15866

# %% [markdown]
# #### 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# 𝜎 = 5 см (кв. корень из D(X))
#
# Отклонение 190 - 178 = 12 см., т.е. на 12/5 = 2,4 сигм. в большую сторону (вправо)

# %% [markdown]
# #### Ответ: на 2,4 сигм "вправо"
