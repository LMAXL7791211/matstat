# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('project/IMDB-Movie-Data.csv')

# %%
data.head(20)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 11    12                           Hidden Figures     Biography,Drama,History
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
# Rank                  1000 non-null int64
# Title                 1000 non-null object
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.8+ KB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 838 entries, 0 to 999
# Data columns (total 12 columns):
# Rank                  838 non-null int64
# Title                 838 non-null object
# Genre                 838 non-null object
# Description           838 non-null object
# Director              838 non-null object
# Actors                838 non-null object
# Year                  838 non-null int64
# Runtime (Minutes)     838 non-null int64
# Rating                838 non-null float64
# Votes                 838 non-null int64
# Revenue (Millions)    838 non-null float64
# Metascore             838 non-null float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.1+ KB

# %%
data.nunique()
# Out:
# Rank                  838
# Title                 837
# Genre                 189
# Description           838
# Director              524
# Actors                834
# Year                   11
# Runtime (Minutes)      90
# Rating                 50
# Votes                 837
# Revenue (Millions)    789
# Metascore              82
# dtype: int64

# %%
# Среднее (оценка матожидания), моды, медианы, квартили, несмещенная оценка среднеквадратичного отклонения:

data.describe(include='all')
# Out:
#                Rank     Title                    Genre  \
# count    838.000000       838                      838
# unique          NaN       837                      189
# top             NaN  The Host  Action,Adventure,Sci-Fi
# freq            NaN         2                       50
# mean     485.247017       NaN                      NaN
# std      286.572065       NaN                      NaN
# min        1.000000       NaN                      NaN
# 25%      238.250000       NaN                      NaN
# 50%      475.500000       NaN                      NaN
# 75%      729.750000       NaN                      NaN
# max     1000.000000       NaN                      NaN
#
#                                               Description      Director  \
# count                                                 838           838
# unique                                                838           524
# top     Aliens and their Guardians are hiding on Earth...  Ridley Scott
# ...

# %%
nrev = len(data['Revenue (Millions)'])
nrev
# Out:
# 838

# %%
#  смещенная оценка среднеквадратичного отклонения данных по выручке:
print (data['Revenue (Millions)'].std(ddof=0))
print ((np.sum((data['Revenue (Millions)'] - data['Revenue (Millions)'].mean()) ** 2 ) / nrev) ** 0.5)
# Out:
# 104.45784501390139
# 104.45784501390143

# %%
# Оценка дисперсии данных по выручке (смещенная и несмещенная):
print (data['Revenue (Millions)'].std(ddof=0) ** 2)
print (data['Revenue (Millions)'].var(ddof=0))
print (data['Revenue (Millions)'].std(ddof=1) ** 2)
print (data['Revenue (Millions)'].var(ddof=1))
# Out:
# 10911.441384948244
# 10911.441384948243
# 10924.477754583784
# 10924.477754583784

# %%
plt.hist(data['Revenue (Millions)'], bins = 20);

# %%
import seaborn as sns

# %%
sns.boxplot(data['Revenue (Millions)'], orient='v');
plt.show()

# %% [markdown]
# Из имеющегося набора данных по выручке сформируем 300 выборок по 10 наблюдений и рассмотрим распределение средних значений:

# %%
np.random.seed(42)

# %%
mean_values = []

# %%
for _ in range(300):
    sample = data.loc[:, 'Revenue (Millions)'].sample(n=10).values
    mean_values.append(sample.mean())
len(mean_values)
# Out:
# 300

# %%
mean_values = np.array(mean_values)

# %%
plt.hist(mean_values, bins=10);

# %% [markdown]
# По гистограмме видно - распределение похоже на нормальное.

# %% [markdown]
# Определим корреляцию признаков

# %%
data.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.312809          -0.254783 -0.243125 -0.303284
# Year               -0.312809  1.000000          -0.101933 -0.145703 -0.362445
# Runtime (Minutes)  -0.254783 -0.101933           1.000000  0.374566  0.399298
# Rating             -0.243125 -0.145703           0.374566  1.000000  0.517452
# Votes              -0.303284 -0.362445           0.399298  0.517452  1.000000
# Revenue (Millions) -0.273170 -0.129198           0.281721  0.217106  0.636833
# Metascore          -0.195909 -0.062303           0.221397  0.672731  0.332674
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.273170  -0.195909
# Year                         -0.129198  -0.062303
# Runtime (Minutes)             0.281721   0.221397
# Rating                        0.217106   0.672731
# Votes                         0.636833   0.332674
# ...

# %% [markdown]
# Таблица корреляции показывает, что есть корреляция между параметрами Votes и Revenue, а также Rating и Metascore

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data[numerical_columns], alpha=0.1, figsize=(15, 15));

# %% [markdown]
# Построим линейную регрессию между Votes и Revenue:

# %%
x = np.array([data['Votes'] / 1000]) # единица измерения Votes - тысяча голосов
y = np.array([data['Revenue (Millions)']])

# %% [markdown]
# $$b = \frac{\overline{yx} - \overline{y} \cdot {\overline{x}}}{\overline{x^2} - (\overline{x})^2};$$

# %% [markdown]
# $$a = \overline{y} - b \cdot {\overline{x}}.$$

# %%
b = (np.mean(x * y) - np.mean(x) * np.mean(y)) / (np.mean(x**2) - np.mean(x) ** 2)
b
# Out:
# 0.34470377301101546

# %%
a = np.mean(y) - b * np.mean(x)
a
# Out:
# 17.957361620680402

# %%
r = b * np.std(x) / np.std(y)
r
# Out:
# 0.636833250670002

# %%
R2 = r**2
R2
# Out:
# 0.40555658915892157

# %% [markdown]
# Качество модели найдем с помощью средней ошибки аппроксимации $\overline {A}$:

# %%
y_pred = a + b * x
A_mean = (100 / y.mean()) * ((np.sum((y - y_pred) ** 2) / nrev) ** 0.5)
A_mean
# Out:
# 95.23748870088313

# %% [markdown]
# Так как $\overline {A}$ равна 95%, что превышает 8-10 %, модель плохо описывает эмпирические данные. Для оценки значимости уравнения регрессии воспользуемся F-критерием Фишера. Найдем фактическое значение $F$-критерия ($F_{факт}$):

# %%
F_fact = (r**2 * (n - 2)) / (1 - r**2)
F_fact
# Out:
# 593.5539466558075

# %% [markdown]
# При 5 % уровне значимости и степенях свободы $k_1 = 1$ и $k_2 > 200$ табличное значение критерия: $F_{кр} = 3.84$.
#
# Так как $F_{факт} = 593 > F_{кр} = 3.84$, уравнение регрессии статистически значимо.

# %% [markdown]
# Для оценки статистической значимости параметров регрессии воспользуемся $t$-статистикой Стьюдента и также рассчитаем
#
# доверительные интервалы каждого из показателей. При $df > 500$ и $\alpha = 0.05$ получим
#
# (см. <a href='https://statpsy.ru/t-student/t-test-tablica/'>Таблицу критических значений t-критерия Стьюдента</a>):

# %% [markdown]
# $$t_{кр} = 1.96$$

# %% [markdown]
# Определим стандартную ошибку $S_{ост}$ (переменная **s_residual**) и случайные ошибки $m_a, \; m_b$:

# %%
s_residual = np.sqrt(np.sum((y - y_pred)**2) / (nrev - 2))
m_a = s_residual * np.sqrt(np.sum(x ** 2)) / (nrev * np.std(x))
m_b = s_residual / (np.std(x) * np.sqrt(nrev))

print('s_residual = {}\nm_a = {}\nm_b = {}'.format(s_residual, m_a, m_b))
# Out:
# s_residual = 80.63344058961928
# m_a = 3.9417178922644402
# m_b = 0.014433525576917457

# %% [markdown]
# Вычислим наблюдаемые значения критерия $t_a$ и $t_b$:

# %%
t_a = a / m_a
t_a
# Out:
# 4.555719640901101

# %%
t_b = b / m_b
t_b
# Out:
# 23.882160403157247

# %% [markdown]
# Фактические значения t-статистики больше табличного значения:

# %% [markdown]
# $$t_a = 4.56 > t_{кр} = 1.96, \; t_b = 23.88 > t_{кр} = 1.96,$$

# %% [markdown]
# поэтому параметры $a$ и $b$ не случайно отличаются от нуля, то есть они статистически значимы.

# %% [markdown]
# Рассчитаем доверительные интервалы для параметров регрессии $a$ и $b$. Для этого определим предельную ошибку для каждого показателя ($\Delta_a$ и $\Delta_b$),
#
# используя значение $t_{кр}$, равное 1.96 (переменная **t_cr**):

# %%
t_cr = 1.96

# %%
delta_a = t_cr * m_a
delta_a
# Out:
# 7.725767068838302

# %%
delta_b = t_cr * m_b
delta_b
# Out:
# 0.028289710130758216

# %% [markdown]
# Найдем границы доверительных интервалов $\gamma_{a_{min}}, \gamma_{a_{max}}, \gamma_{b_{min}}, \gamma_{b_{max}}$:

# %%
gamma_a_min = a - delta_a
gamma_a_max = a + delta_a

print(f'Доверительный интервал для а: {gamma_a_min} , {gamma_a_max}')

gamma_b_min = b - delta_b
gamma_b_max = b + delta_b
print(f'Доверительный интервал для b: {gamma_b_min} , {gamma_b_max}')
# Out:
# Доверительный интервал для а: 10.2315945518421 , 25.683128689518703
# Доверительный интервал для b: 0.31641406288025725 , 0.37299348314177366

# %% [markdown]
# Приходим к выводу о том, что с вероятностью $p = 1 - \alpha = 0.95$ параметры $a$ и $b$, находясь в указанных границах,
#
# являются статистически значимыми и отличны от нуля. Поместим исходные и предсказанные данные в датафрейм **df**:

# %%
df = pd.DataFrame({'x': x[0], 'y': y[0], 'y_pred': y_pred[0]}, columns=['x', 'y', 'y_pred'])
df.head()
# Out:
#          x       y      y_pred
# 0  757.074  333.13  278.923626
# 1  485.820  126.46  185.421349
# 2  157.606  138.12   72.284744
# 3   60.545  270.32   38.827452
# 4  393.727  325.02  153.676544

# %%
df = df.sort_values('x')
df.head()
# Out:
#          x      y     y_pred
# 222  0.178   0.32  18.018719
# 536  0.277  20.76  18.052845
# 37   0.279   4.21  18.053534
# 58   0.291   0.01  18.057670
# 475  0.391   0.11  18.092141

# %%
plt.scatter(df['x'], df['y']);
plt.plot(df['x'], df['y_pred'], color='red');
plt.xlabel('Votes (thousands)')
plt.ylabel('Revenue (Million USD)')
# Out:
# Text(0, 0.5, 'Revenue (Million USD)')
